# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('datasets/water_potability.csv')
df[df.isnull().any(axis=1)]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 8          NaN  118.988579  14285.583854     7.804174  268.646941
# 11    7.974522  218.693300  18767.656682     8.110385         NaN
# ...        ...         ...           ...          ...         ...
# 3266  8.372910  169.087052  14622.745494     7.547984         NaN
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 8       389.375566       12.706049        53.928846   3.595017           0
# 11      364.098230       14.525746        76.485911   4.011718           0
# ...            ...             ...              ...        ...         ...
# 3266    464.525552       11.083027        38.435151   4.906358           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [1265 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
potabilities = df.Potability.sort_values().unique()
potabilities
# Out:
# array([0, 1])

# %%
df.loc[df.ph.isna()]
df.loc[df.Sulfate.isna()]
df.loc[df.Trihalomethanes.isna()]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 62         NaN  229.485694  35729.692709     8.810843  384.943779
# 81    5.519126  168.728583  12531.601921     7.730723         NaN
# 110   9.286155  222.661551  12311.268366     7.289866  332.239359
# 118   7.397413  122.541040   8855.114121     6.888689  241.607532
# 119   7.812804  196.583886  42550.841816     7.334648         NaN
# ...        ...         ...           ...          ...         ...
# 3174  6.698154  198.286268  34675.862845     6.263602  360.232834
# 3185  6.110022  234.800957  16663.539074     5.984536  348.055211
# 3219  6.417716  209.702425  31974.481631     7.263425  321.382124
# 3259  9.271355  181.259617  16540.979048     7.022499  309.238865
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 62      296.397547       16.927092              NaN   3.855602           0
# 81      443.570372       18.099078              NaN   3.758996           0
# 110     353.740100       14.171763              NaN   5.239982           0
# 118     489.851600       13.365906              NaN   3.149158           0
# 119     442.545775       14.666917              NaN   6.204846           0
# ...            ...             ...              ...        ...         ...
# 3174    430.935009       12.176678              NaN   3.758180           1
# 3185    437.892115       10.059523              NaN   2.817780           1
# 3219    289.450118       11.369071              NaN   4.210327           1
# 3259    487.692788       13.228441              NaN   4.333953           1
# 3272    392.449580       19.903225              NaN   2.798243           1
#
# [162 rows x 10 columns]

# %%
df = df.drop(df[(df.ph.isna()) & (df.Sulfate.isna()) & (df.Trihalomethanes.isna())].index)
df = df.drop(df[(df.ph.isna()) & (df.Sulfate.isna())].index)
df = df.drop(df[(df.ph.isna()) & (df.Trihalomethanes.isna())].index)
df = df.drop(df[(df.Sulfate.isna()) & (df.Trihalomethanes.isna())].index)
df.loc[df.isna().any(axis=1)]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 8          NaN  118.988579  14285.583854     7.804174  268.646941
# 11    7.974522  218.693300  18767.656682     8.110385         NaN
# ...        ...         ...           ...          ...         ...
# 3259  9.271355  181.259617  16540.979048     7.022499  309.238865
# 3266  8.372910  169.087052  14622.745494     7.547984         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 8       389.375566       12.706049        53.928846   3.595017           0
# 11      364.098230       14.525746        76.485911   4.011718           0
# ...            ...             ...              ...        ...         ...
# 3259    487.692788       13.228441              NaN   4.333953           1
# 3266    464.525552       11.083027        38.435151   4.906358           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [1105 rows x 10 columns]

# %%
df.fillna(df.mean(), inplace=True)
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.078708  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.699670
# 2     8.099124  224.236259  19909.541732     9.275884  333.699670
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3270  6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3273  9.419510  175.762646  33155.578218     7.350233  333.699670
# 3274  5.126763  230.603758  11983.869376     6.303357  333.699670
# 3275  7.874671  195.102299  17404.177061     7.509306  333.699670
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3270    415.886955       12.067620        60.419921   3.669712           1
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3116 rows x 10 columns]

# %%
# split the data int x(training data) and y (results)

y = df['Conductivity']
x = df.drop(['Conductivity', 'Trihalomethanes'], axis=1)
x = pd.get_dummies(x)
y = pd.get_dummies(y)
x.info()
y.info()
# x.info()
# y.info()
# x.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3116 entries, 0 to 3275
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ph              3116 non-null   float64
#  1   Hardness        3116 non-null   float64
#  2   Solids          3116 non-null   float64
#  3   Chloramines     3116 non-null   float64
#  4   Sulfate         3116 non-null   float64
#  5   Organic_carbon  3116 non-null   float64
#  6   Turbidity       3116 non-null   float64
#  7   Potability      3116 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 219.1 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3116 entries, 0 to 3275
# Columns: 3116 entries, 181.483753985146 to 753.3426195583046
# dtypes: uint8(3116)
# memory usage: 9.3 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
parameters = {'criterion':('gini', 'entropy'), 
              'min_samples_split':[2,3,4,5], 
              'max_depth':[9,10,11,12],
              'class_weight':('balanced', None),
              #'presort':(False,True),
             }

# %%
tr = tree.DecisionTreeClassifier()
gsearch = GridSearchCV(tr, parameters)

# %%
tr.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])

# %%
gsearch
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ('balanced', None),
#                          'criterion': ('gini', 'entropy'),
#                          'max_depth': [9, 10, 11, 12],
#                          'min_samples_split': [2, 3, 4, 5]})

# %%
gsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ('balanced', None),
#                          'criterion': ('gini', 'entropy'),
#                          'max_depth': [9, 10, 11, 12],
#                          'min_samples_split': [2, 3, 4, 5]})

# %%
model = gsearch.best_params_
model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb#ch0000016?line=0'>1</a> model = gsearch.best_params_
#       <a href='vscode-notebook-cell:/home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb#ch0000016?line=1'>2</a> model
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
score = model.score(X_test, y_test)
score
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb Cell 18' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb#ch0000020?line=0'>1</a> score = model.score(X_test, y_test)
#       <a href='vscode-notebook-cell:/home/ioannis/Dev/ml/mldtrees/DT-WaterQ.ipynb#ch0000020?line=1'>2</a> score
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py:646, in ClassifierMixin.score(self, X, y, sample_weight)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=620'>621</a> """
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=621'>622</a> Return the mean accuracy on the given test data and labels.
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=622'>623</a>
#    (...)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=641'>642</a>     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=642'>643</a> """
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=643'>644</a> from .metrics import accuracy_score
# --> <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/base.py?line=645'>646</a> return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py:466, in BaseDecisionTree.predict(self, X, check_input)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=442'>443</a> def predict(self, X, check_input=True):
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=443'>444</a>     """Predict class or regression value for X.
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=444'>445</a>
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=445'>446</a>     For a classification model, the predicted class for each sample in X is
#    (...)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=463'>464</a>         The predicted classes, or the predict values.
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=464'>465</a>     """
# --> <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=465'>466</a>     check_is_fitted(self)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=466'>467</a>     X = self._validate_X_predict(X, check_input)
#     <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=467'>468</a>     proba = self.tree_.predict(X)
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py:1209, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py?line=1203'>1204</a>     fitted = [
#    <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py?line=1204'>1205</a>         v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py?line=1205'>1206</a>     ]
#    <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py?line=1207'>1208</a> if not fitted:
# -> <a href='file:///home/ioannis/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/validation.py?line=1208'>1209</a>     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
